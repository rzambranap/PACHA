# %%
# Library imports cell

from pacha.utils import instruments as iutils
from pacha.utils import file_utils as futils
from pacha.visualisation import geospatial as gvis
from pacha.visualisation import statistical as svis
from pacha.utils import visualisation as vutils
from pacha.utils import geospatial as gutils
from pacha.utils import temporal as tutils
from pacha.data_sources import satellite_loaders as sload
from pacha.L3_processing import regrid as l3reg
import importlib
import matplotlib.pyplot as plt
import xarray as xr
import pandas as pd
import numpy as np
from scipy.signal import convolve2d
import matplotlib.gridspec as gridspec
from datetime import timedelta as td
from pacha.merging import quantile_matching as qmatch
import copy
import warnings
from cartopy import crs as ccrs
from pacha.utils import metrics
from scipy.spatial import distance
import itertools
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
import pickle
from datetime import datetime
import os
from sklearn.cluster import KMeans
import numpy as np
from pacha.utils import ml_utils as aiutils
from datetime import datetime as dt
import cartopy.feature as cfeature


importlib.reload(metrics)
importlib.reload(qmatch)
importlib.reload(iutils)
importlib.reload(gvis)
importlib.reload(gutils)
# Out:
# <module 'pacha.utils.geospatial' from '/home/admingosset/WORK/code/PACHA/pacha/utils/geospatial.py'>

# %%
# Specific functions definition

def infer_step_length(df):
    step_length = np.median(np.diff(df.index))
    return pd.to_timedelta(step_length)

def average_radar_inside_gauge_timesteps(gau_df, rad_df):
    step_length = infer_step_length(gau_df)
    min_val = rad_df.rain_rate.min()
    matched_rad = rad_df.replace(min_val, 0).groupby(pd.Grouper(freq=step_length)).mean()
    matched_rad.index = matched_rad.index + step_length
    return gau_df, matched_rad

def based_on_scope_retrieve_gauge_radar_data(scopy, gauges, radar):
    ids = scopy.index.tolist()

    dfs_by_id = {id:[] for id in ids}

    if len(scopy.index) <= 1:
        nlist = scopy.loc[scopy.index[0], 'dates']

    else:
        nlist = sorted(list(set(np.concatenate([l for l in scopy.loc[:, 'dates'].tolist()]))))

    idxs_by_date = {d: [] for d in nlist}
    for date in nlist:
        for idx in scopy.index:
            if date in scopy.loc[idx, 'dates']:
                idxs_by_date[date].append(idx)

    for date in nlist:
        ds_rad = radar.load_sample(date)
        for idx in idxs_by_date[date]:
            long, latg = gauges.get_coords_station(idx)
            rad_df = gutils.ds_to_df_at_point(ds_rad, (long, latg))
            gau_df = gauges.data.loc[date, idx]
            #rad_matched, gau_matched = tutils.align_dataframes_by_time_fixed(rad_df, gau_df)
            gau_matched, rad_matched = average_radar_inside_gauge_timesteps(gau_df, rad_df)
            gau_rate = gau_matched * 10
            rad_gau_df = pd.concat([rad_matched, gau_rate], axis=1)
            dfs_by_id[idx].append(rad_gau_df)

    return dfs_by_id


def visualize_scope(scopy, gauges, ax=None, fig=None):
    if len(scopy.index) <= 1:
        nlist = scopy.loc[scopy.index[0], 'dates']
    
    else:
        nlist = sorted(list(set(np.concatenate([l for l in scopy.loc[:, 'dates'].tolist()]))))
    
    if (fig is None) or (ax is None):
        fig = plt.figure(figsize=(10,3))
        ax = fig.add_subplot(111)
    
    max_date = pd.to_datetime(nlist).max()
    min_date = pd.to_datetime(nlist).min()
    
    monthly_accs = gauges.data.loc[min_date:max_date, scope.index].groupby(pd.Grouper(freq='1m')).sum().replace(0, np.nan)
    
    mean = monthly_accs.mean(axis=1)
    ax.plot_date(mean.index, mean.to_numpy(), fmt= '-k')
    max_accs = mean.max()/2
    ax.scatter(pd.to_datetime(nlist), max_accs * np.ones_like(np.array(nlist), dtype=float), marker='o', s=2000, alpha=0.1, edgecolors='none')
    ax.set_title('Mean monthly accumulations and dates from scope')
    ax.set_ylabel('mm/month')
    ax.set_xlabel('Time')
    return

def simple_romulo_plot(df_data, ids_order=None, columns_to_scale_differently=None, solo_scale=False, **kwargs):
    """
    Plots data from a DataFrame with optional scaling for selected columns.

    This function creates a series of plots for each column in the DataFrame. It supports
    custom scaling for specified columns and can apply a uniform scale across all columns.

    Parameters:
    - df_data (pd.DataFrame): The DataFrame containing the data to plot.
    - ids_order (list, optional): A list specifying the order of columns to plot. If None, the DataFrame's column order is used.
    - columns_to_scale_differently (list, optional): Columns that should be scaled differently from the rest. If solo_scale is True, this is ignored.
    - solo_scale (bool): If True, each column is scaled independently. Defaults to False.
    - **kwargs: Additional keyword arguments to pass to the plotting function.

    Returns:
    - None: Displays a matplotlib plot.
    """
    if not isinstance(df_data, pd.DataFrame):
        raise ValueError("df_data must be a pandas DataFrame.")

    if solo_scale:
        columns_to_scale_differently = df_data.columns.tolist()

    if columns_to_scale_differently is None:
        columns_to_scale_differently = []

    if not isinstance(columns_to_scale_differently, list):
        columns_to_scale_differently = [columns_to_scale_differently]

    if ids_order is None:
        ids_order = df_data.columns.tolist()

    df_data = df_data.loc[:, ids_order]
    cols_in = [col in columns_to_scale_differently for col in ids_order]

    v_min = df_data.loc[:, ~np.array(cols_in)].min().min() if not solo_scale else None
    v_max = df_data.loc[:, ~np.array(cols_in)].max().max() if not solo_scale else None

    n_ids = len(ids_order)
    fig, axes = plt.subplots(nrows=n_ids, sharex=True, figsize=[10, n_ids / 3])
    
    if n_ids == 1:
        axes = [axes]
    
    for uni_id, ax in zip(ids_order, axes):
        data_id = df_data.loc[:, uni_id].to_numpy()
        to_plot = np.reshape(data_id, [len(data_id), 1])
        vmin = to_plot.min() if uni_id in columns_to_scale_differently or solo_scale else v_min
        vmax = to_plot.max() if uni_id in columns_to_scale_differently or solo_scale else v_max
        ax.imshow(to_plot.T, vmin=vmin, vmax=vmax, aspect='auto')
        ax.set_yticks([0])
        ax.set_yticklabels([uni_id])

    xlocs = np.arange(len(df_data.index))
    xlabs = df_data.index.astype(str)
    
    if len(xlocs) > 10:
        step = len(xlocs) // 10
        xlocs = xlocs[::step]
        xlabs = xlabs[::step]

    plt.xticks(xlocs, xlabs, rotation='vertical')
    plt.subplots_adjust(hspace=0)
    plt.show()


def visualize_fuser(fuser, params, x=np.linspace(0, 10, 100), label=None, ax=None):
    if fuser.fusing_params['sep_land_sea']:
        land_params = params['land_params']
        sea_params = params['sea_params']
        label_sea = f'{label}_sea_params' if label is not None else ""
        label_land = f'{label}_land_params' if label is not None else ""
        fuser_copy = copy.deepcopy(fuser)
        fuser_copy.fusing_params['sep_land_sea'] = False
        visualize_fuser(fuser_copy, land_params, x=x, label=label_land, ax=ax)
        visualize_fuser(fuser_copy, sea_params, x=x, label=label_sea, ax=ax)
    else:
        if ax is None:
            ax = plt.gca()
        if 'land' in label:
            ls = '-'
        elif 'sea' in label:
            ls = '--'
        else:
            ls = '-.'
        ax.plot(x, fuser.low_level_applier(x, params), label=label, ls=ls)
        return


def decide_type_plot(ds):
    dims = ds.dims
    ndims = len(dims)
    if ndims == 1:
        return 'time_series_plot'
    elif ndims == 2:
        return 'spatial_plot'
    else:
        raise ValueError(f'{ndims} dims in dataset, not yet taken into account')


def plot_ds(ds, joint=False, plot_map=True, match_scale=True, pcp_var=None, vmmax=None):
    vars = list(ds.data_vars)
    nvars = len(vars)

    global_min = np.min(np.array([ds[var].min().values for var in vars]))
    global_max = np.max(np.array([ds[var].max().values for var in vars]))

    plot_type = decide_type_plot(ds)

    figsize = ((7+2)*nvars, 7)
    fig, axes = plt.subplots(1,
                             nvars,
                             subplot_kw=dict(projection=ccrs.PlateCarree()),
                             figsize=figsize)

    for i in range(nvars):
        ax = axes[i]
        var = vars[i]
        if plot_map:
            gvis.plot_simple_map(ax=ax)
        vmin, vmax = ds[var].min().values, ds[var].max().values

        if match_scale:
            vmin, vmax = global_min, global_max
        if vmmax is not None:
            vmax = vmmax
        ds[var].plot(x='lon', y='lat', ax=ax, vmin=vmin, vmax=vmax)
        ax.set_title(var)
    return


def from_ds_calc_single_step_spatial_correl(ds, ref_var='rain_rate'):
    tvar = ds.time.to_numpy()
    corr_list = [ds.isel({'time':i}).to_dataframe().loc[:, vars].corr().loc[:, ref_var] for i in range(len(tvar))]
    correl_df = pd.concat(corr_list, axis=1).T
    correl_df.index = tvar
    return correl_df


def calc_score_for_ds_multip_vars(ds, score_fct):
    ds_qmp = ds.drop_vars('precipitationCal')
    ds_nor = ds.drop_vars('precipitationCal_matched')
    
    tvar = ds.time.to_numpy()
    
    nsteps = len(tvar)
    rb_qmp = [score_fct(ds_qmp.isel({'time': i}), char_pcp='rain') for i in range(nsteps)]
    rb_nor = [score_fct(ds_nor.isel({'time': i}), char_pcp='rain') for i in range(nsteps)]
    score_key = list(rb_qmp[0].keys())[0]
    rb_qmp = [i[score_key] for i in rb_qmp]
    rb_nor = [i[score_key] for i in rb_nor]
    
    scores_dict = {'time': tvar,
                   'rbias_qmp': rb_qmp,
                   'rbias_nor': rb_nor}
    
    df_score = pd.DataFrame.from_dict(scores_dict)
    df_score = df_score.set_index('time')
    return df_score


def single_array_2dconv(arr):
    arr = convolve2d(arr, kernel, mode='same')
    return arr


def plot_median_2_quantiles(ds, var, ax=None, quantiles=[0.25, 0.75], c='b', threshold=0, **kwargs):
    if ax is None:
        ax = plt.gca()
    ds = ds.where(ds > threshold)
    ds[var].median(dim=['lat', 'lon']).plot(c=c, ax=ax, **kwargs)
    df = ds[var].quantile(quantiles, dim=['lon', 'lat']
                          ).to_dataframe().unstack().transpose()
    quant1 = df.iloc[:, 0].values
    quant2 = df.iloc[:, 1].values
    time = df.iloc[:, 0].loc[var].index.to_numpy()
    ax.fill_between(time, quant1, quant2, color=c, alpha=0.2)
    return


def calc_dist_to_median(ds, char_pcp='rain', threshold=.5):
    fields = list(ds.keys())
    if len(fields) != 2:
        raise ValueError('for this function to work a dataset with two variables must be input, here there are ' +
                         str(len(fields)) + ' fields')

    idx_pcp = [i for i in range(0, len(fields)) if char_pcp in fields[i]][0]
    field1 = fields.pop(idx_pcp)
    field2 = fields[0]
    cond_median = (ds.where(ds > threshold)).median(dim=['lat', 'lon'])
    dist_to_median = cond_median[field2] - cond_median[field1]
    dist_to_median = dist_to_median.values
    out_dict = {'distance_to_the_median': dist_to_median}
    return(out_dict)



def add_dist_metric(grid, lat0=None, lon0=None):
    """
    Add distance metric to the input grid.
    The distance is calculated as the euclidean distance from the grid cell to the specified coordinates (lat0, lon0).
    If no coordinates are specified, the mean latitude and longitude of the grid are used.

    Parameters
    ----------
    grid: xarray.DataArray
        Input grid with coordinates 'lat' and 'lon'.
    lat0: float, optional
        Latitude of the reference point. Default is None.
    lon0: float, optional
        Longitude of the reference point. Default is None.

    Returns
    -------
    xarray.Dataset
        The input grid with an additional distance metric ('dists') calculated as the euclidean distance from the grid
        cell to (lat0, lon0).
    """
    if (lat0 is None) or (lon0 is None):
        lat0 = grid.lat.mean()
        lon0 = grid.lon.mean()

    shape = (grid.lat.shape[0], grid.lon.shape[0])
    full_coords = list(itertools.product(grid.lat, grid.lon))

    center = [[lat0, lon0]]
    dists = distance.cdist(full_coords, center).reshape(shape)
    if isinstance(grid, xr.DataArray):
        test_to_add = grid.to_dataset(name='rain_rate')
    else:
        test_to_add = grid.copy()
    test_to_add['dists'] = (['lat', 'lon'], dists)
    return test_to_add


def get_lon_lat_dist(test_L2):
    """
    Calculate the distance between the minimum and maximum longitude and latitude in a given xarray dataset and the
    center of the array.
    Also return the coordinates (latitude, longitude) of the center of the bounding box defined by the min and max
    lat and lon.

    Parameters:
    - test_L2 (xarray.Dataset): xarray dataset containing longitude and latitude coordinates.

    Returns:
    - dist (float): distance between min and max longitude and latitude in the xarray dataset.
    - (lat0, lon0) (tuple): coordinates of the center of the bounding box defined by the min and max lat and lon.
    """
    lon_max = test_L2.lon.max()
    lat_max = test_L2.lat.max()
    lon_min = test_L2.lon.min()
    lat_min = test_L2.lat.min()

    dist_lon = ((lon_max - lon_min) / 2).data
    dist_lat = ((lat_max - lat_min) / 2).data

    dist = (dist_lon + dist_lat) / 2

    lon0 = ((lon_max + lon_min) / 2).data
    lat0 = ((lat_max + lat_min) / 2).data
    return (dist, (lat0, lon0))


def calculate_features_for_clustering(x, threshold=1.5):
    
    if not isinstance(x, (xr.Dataset, xr.DataArray)):
        raise TypeError(f"input isn't of valid type, valid types are xr.Dataset or xr.DataArray,\nx is {type(x)}")
    
    needed_dims = ['lat', 'lon']
    
    is_ds = isinstance(x, xr.Dataset)
    is_da = isinstance(x, xr.DataArray)
    
    if is_ds:
        dvars = list(x.data_vars)
        dims = x[dvars[0]].dims
    if is_da:
        dims = x.dims
    
    
    present_dims = set(dims)
    
    if not all(x in present_dims for x in needed_dims):
        raise TypeError(f'needed dims are {needed_dims}, x only has {present_dims}')
    
    if is_ds:
        dvars = list(x.data_vars)
        single_tstep = x[dvars[0]].isel({"time":0})
        cols = dvars
    if is_da:
        try:
            single_tstep = x.isel({'time':0})
        except Exception as e:
            print(e)
            print('defaulting to single step issue')
            single_tstep = x
        cols = [x.name]
    
    nvalid_pixels = single_tstep.count().values
    support_over_threshold = ((x > threshold).sum(dim=['lat', 'lon']))
    
    spm = (x.mean(dim=['lat', 'lon'])).to_dataframe().loc[:, cols]
    sup = (support_over_threshold/nvalid_pixels).to_dataframe().loc[:, cols]
    std = x.std(dim=['lat', 'lon']).to_dataframe().loc[:, cols]
    cvr = std/spm
    
    features = [spm, sup, std, cvr]
    feat_names = ['spm', 'sup', 'std', 'cvr']
    
    #spm.columns = [f'spm_{i}' for i in cols]
    #sup.columns = [f'sup_{i}' for i in cols]
    #std.columns = [f'std_{i}' for i in cols]
    #cvr.columns = [f'cvr_{i}' for i in cols]
    
    features_by_var = {col: None for col in cols}
    for col in cols:
        feats = pd.concat([feature.loc[:, col] for feature in features], axis=1)
        feats.columns = feat_names
        features_by_var[col] = feats
    return features_by_var


def save_to_pickle(model, directory):
    # Get the current date and time
    now = datetime.now()
    timestamp = now.strftime("%Y%m%d_%H%M%S")
    
    # Create the filename
    filename = f'k_means_model_{timestamp}.pkl'
    
    # Ensure the directory exists
    os.makedirs(directory, exist_ok=True)
    
    # Full path to save the model
    filepath = os.path.join(directory, filename)
    
    # Save the model
    with open(filepath, 'wb') as file:
        pickle.dump(model, file)
        
    print(f"Model saved to {filepath}")


def load_from_pickle(filepath):
    # Load the model from the specified file
    with open(filepath, 'rb') as file:
        model = pickle.load(file)
    return model


def are_models_equal(model1, model2):
    attributes = [
        'n_clusters', 'cluster_centers_', 'labels_', 
        'inertia_', 'n_iter_', 'random_state'
    ]
    
    for attr in attributes:
        if not np.array_equal(getattr(model1, attr, None), getattr(model2, attr, None)):
            return False
    return True


def subdivide_dataset(ds, nsubdivisions):
    """
    Subdivide the given dataset into nsubdivisions x nsubdivisions equal parts.
    
    Parameters:
    ds (xarray.Dataset): The input dataset.
    nsubdivisions (int): The number of subdivisions along each dimension (lat and lon).
    
    Returns:
    List[xarray.Dataset]: A list of subdivided datasets.
    """
    lon_splits = np.array_split(ds.lon, nsubdivisions)
    lat_splits = np.array_split(ds.lat, nsubdivisions)
    
    subsets = []
    for i in range(nsubdivisions):
        for j in range(nsubdivisions):
            subset = ds.sel(lon=lon_splits[j], lat=lat_splits[i])
            subsets.append(subset)
    
    return subsets

# %%
fpath_calib = 'v6_vs_v7_vs_qp.nc'
ds_calib = xr.open_dataset(fpath_calib)

display(ds_calib)
mask = ~ np.isnan(ds_calib.imerg_v7.isel(time=0))
ds_calib = ds_calib.fillna(0).where(mask)
gvis.plot_ds(ds_calib.isel({'time':0}))
# Out:
# <xarray.Dataset> Size: 346MB
# Dimensions:          (time: 16801, lat: 26, lon: 33)
# Coordinates:
#   * time             (time) datetime64[ns] 134kB 2019-01-09 ... 2022-12-26T23...
#   * lon              (lon) float32 132B -54.25 -54.15 -54.05 ... -51.15 -51.05
#   * lat              (lat) float32 104B 3.45 3.55 3.65 3.75 ... 5.75 5.85 5.95
#     elevation        float64 8B ...
# Data variables:
#     imerg_v6         (time, lat, lon) float32 58MB ...
#     imerg_v7         (time, lat, lon) float32 58MB ...
#     radar_rain_rate  (time, lat, lon) float64 115MB ...
#     qmp_v6           (time, lat, lon) float64 115MB ...
# Error in callback <function _draw_all_if_interactive at 0x79f597bae680> (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/miniconda3/envs/pacha/lib/python3.10/site-packages/matplotlib/pyplot.py:278, in _draw_all_if_interactive()
#     276 def _draw_all_if_interactive() -> None:
#     277     if matplotlib.is_interactive():
# --> 278         draw_all()
#
# File ~/miniconda3/envs/pacha/lib/python3.10/site-packages/matplotlib/_pylab_helpers.py:131, in Gcf.draw_all(cls, force)
#     129 for manager in cls.get_all_fig_managers():
#     130     if force or manager.canvas.figure.stale:
# --> 131         manager.canvas.draw_idle()
#
# File ~/miniconda3/envs/pacha/lib/python3.10/site-packages/matplotlib/backend_bases.py:1893, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    1891 if not self._is_idle_drawing:
#    1892     with self._idle_draw_cntx():
# -> 1893         self.draw(*args, **kwargs)
#
# File ~/miniconda3/envs/pacha/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:382, in FigureCanvasAgg.draw(self)
#     379 # Acquire a lock on the shared font cache.
#     380 with (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     381       else nullcontext()):
# --> 382     self.figure.draw(self.renderer)
#     383     # A GUI class may be need to update a window using this draw, so
#     384     # don't forget to call the superclass.
#     385     super().draw()
#
# File ~/miniconda3/envs/pacha/lib/python3.10/site-packages/matplotlib/artist.py:94, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      92 @wraps(draw)
#      93 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 94     result = draw(artist, renderer, *args, **kwargs)
#      95     if renderer._rasterizing:
#      96         renderer.stop_rasterizing()
#
# File ~/miniconda3/envs/pacha/lib/python3.10/site-packages/matplotlib/artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File ~/miniconda3/envs/pacha/lib/python3.10/site-packages/matplotlib/figure.py:3257, in Figure.draw(self, renderer)
#    3254             # ValueError can occur when resizing a window.
#    3256     self.patch.draw(renderer)
# -> 3257     mimage._draw_list_compositing_images(
#    3258         renderer, self, artists, self.suppressComposite)
#    3260     renderer.close_group('figure')
#    3261 finally:
#
# File ~/miniconda3/envs/pacha/lib/python3.10/site-packages/matplotlib/image.py:134, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132 if not_composite or not has_images:
#     133     for a in artists:
# --> 134         a.draw(renderer)
#     135 else:
#     136     # Composite any adjacent images together
#     137     image_group = []
#
# File ~/miniconda3/envs/pacha/lib/python3.10/site-packages/matplotlib/artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File ~/miniconda3/envs/pacha/lib/python3.10/site-packages/cartopy/mpl/geoaxes.py:509, in GeoAxes.draw(self, renderer, **kwargs)
#     504         self.imshow(img, extent=extent, origin=origin,
#     505                     transform=factory.crs, *factory_args[1:],
#     506                     **factory_kwargs)
#     507 self._done_img_factory = True
# --> 509 return super().draw(renderer=renderer, **kwargs)
#
# File ~/miniconda3/envs/pacha/lib/python3.10/site-packages/matplotlib/artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File ~/miniconda3/envs/pacha/lib/python3.10/site-packages/matplotlib/axes/_base.py:3226, in _AxesBase.draw(self, renderer)
#    3223 if artists_rasterized:
#    3224     _draw_rasterized(self.get_figure(root=True), artists_rasterized, renderer)
# -> 3226 mimage._draw_list_compositing_images(
#    3227     renderer, self, artists, self.get_figure(root=True).suppressComposite)
#    3229 renderer.close_group('axes')
#    3230 self.stale = False
#
# File ~/miniconda3/envs/pacha/lib/python3.10/site-packages/matplotlib/image.py:134, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132 if not_composite or not has_images:
#     133     for a in artists:
# --> 134         a.draw(renderer)
#     135 else:
#     136     # Composite any adjacent images together
#     137     image_group = []
#
# File ~/miniconda3/envs/pacha/lib/python3.10/site-packages/matplotlib/artist.py:38, in _prevent_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      35     renderer.stop_rasterizing()
#      36     renderer._rasterizing = False
# ---> 38 return draw(artist, renderer, *args, **kwargs)
#
# File ~/miniconda3/envs/pacha/lib/python3.10/site-packages/cartopy/mpl/gridliner.py:1256, in Gridliner.draw(self, renderer)
#    1255 def draw(self, renderer=None):
# -> 1256     self._draw_gridliner(renderer=renderer)
#    1257     for c in self.get_visible_children():
#    1258         c.draw(renderer=renderer)
#
# File ~/miniconda3/envs/pacha/lib/python3.10/site-packages/cartopy/mpl/gridliner.py:921, in Gridliner._draw_gridliner(self, nx, ny, renderer)
#     918     y = pt0[1]
#     920 # Update generated label.
# --> 921 label = next(generate_labels)
#     922 text = formatter(tick_value)
#     923 artist = label.artist
#
# File ~/miniconda3/envs/pacha/lib/python3.10/site-packages/cartopy/mpl/gridliner.py:593, in Gridliner._generate_labels(self)
#     589     yield label
#     591 while True:
#     592     # Ran out of existing labels.  Create some empty ones.
# --> 593     new_artist = matplotlib.text.Text()
#     594     new_artist.set_figure(self.axes.figure)
#     595     new_artist.axes = self.axes
#
# File ~/miniconda3/envs/pacha/lib/python3.10/site-packages/matplotlib/text.py:139, in Text.__init__(self, x, y, text, color, verticalalignment, horizontalalignment, multialignment, fontproperties, rotation, linespacing, rotation_mode, usetex, wrap, transform_rotates_text, parse_math, antialiased, **kwargs)
#     137 self._x, self._y = x, y
#     138 self._text = ''
# --> 139 self._reset_visual_defaults(
#     140     text=text,
#     141     color=color,
#     142     fontproperties=fontproperties,
#     143     usetex=usetex,
#     144     parse_math=parse_math,
#     145     wrap=wrap,
#     146     verticalalignment=verticalalignment,
#     147     horizontalalignment=horizontalalignment,
#     148     multialignment=multialignment,
#     149     rotation=rotation,
#     150     transform_rotates_text=transform_rotates_text,
#     151     linespacing=linespacing,
#     152     rotation_mode=rotation_mode,
#     153     antialiased=antialiased
#     154 )
#     155 self.update(kwargs)
#
# File ~/miniconda3/envs/pacha/lib/python3.10/site-packages/matplotlib/text.py:183, in Text._reset_visual_defaults(self, text, color, fontproperties, usetex, parse_math, wrap, verticalalignment, horizontalalignment, multialignment, rotation, transform_rotates_text, linespacing, rotation_mode, antialiased)
#     181 self.set_horizontalalignment(horizontalalignment)
#     182 self._multialignment = multialignment
# --> 183 self.set_rotation(rotation)
#     184 self._transform_rotates_text = transform_rotates_text
#     185 self._bbox_patch = None  # a FancyBboxPatch instance
#
# File ~/miniconda3/envs/pacha/lib/python3.10/site-packages/matplotlib/text.py:1227, in Text.set_rotation(self, s)
#    1224     self._y = y
#    1225     self.stale = True
# -> 1227 def set_rotation(self, s):
#    1228     """
#    1229     Set the rotation of the text.
#    1230
#    (...)
#    1235         (counterclockwise). 'horizontal' equals 0, 'vertical' equals 90.
#    1236     """
#    1237     if isinstance(s, Real):
#
# KeyboardInterrupt:

# %%
### Determine your fuser

def test_func(x, a, b, c):
    return a*x**2 + b*x + c
fuser = qmatch.Fuser({'method': 'quantile_matching_by_parts', 'reference_variable': 'rain_rate', 'sep_land_sea':True, 'func': test_func})

# %%
### method 2 : load saved classifier, train pdf matching params, check results

ds = copy.deepcopy(ds_calib)
ds = ds[['imerg_v7', 'radar_rain_rate']]
#train = train.where(train.precipitationCal>0)
#test = test.where(test.precipitationCal>0)

train, test = aiutils.split_dataset(ds)

# initialize kmeans
#kmeans = load_from_pickle('kmean_models/k_means_model_20240801_110831.pkl')

# initialize kmeans
kmeans = KMeans(n_clusters=4, random_state=12)
nclusters = kmeans.n_clusters

#determine features with no nans
features_df = calculate_features_for_clustering(train)['imerg_v7'].dropna()

#train kmeans
kmeans.fit(features_df)


nclusters = kmeans.n_clusters

#determine features with no nans
features_df = calculate_features_for_clustering(train)['imerg_v7'].dropna()

#add labels
features_df.loc[:, 'label'] = kmeans.predict(features_df)

#separate time steps by label
dates_by_label = {i: sorted(features_df.loc[features_df.label==i].index) for i in range(nclusters)}

#separate dataset by labels
dss_by_label = {i: train.sel({'time': dates_by_label[i]}) for i in range(nclusters)}

#calculate pdf matching params by label
params_by_label = {i: fuser.calculate_fusing_params(dss_by_label[i]) for i in range(nclusters)}

#export train matched dss by label
train_resulting_dss = {i: fuser.export_matching_ds(dss_by_label[i]) for i in range(nclusters)}

#ensure no duplicates and set them to be merged
train_land_dss = []
for label in range(nclusters):
    fused_ds = train_resulting_dss[label]
    land_ds = fused_ds.drop_duplicates('time')
    train_land_dss.append(land_ds)

#merge them
train_merged = xr.merge(train_land_dss)

#bias evaluation
no_match_bias = metrics.calc_rel_bias(train_merged.drop_vars('imerg_v7_matched'), char_pcp='rain')
matched_bias = metrics.calc_rel_bias(train_merged.drop_vars('imerg_v7'), char_pcp='rain')

print('for train dataset')
print(f'no matching:\t{no_match_bias}\nmatching:\t{matched_bias}')

#apply to testing dataset
features_test = calculate_features_for_clustering(test)['imerg_v7'].dropna()

features_test.loc[:, 'label'] = kmeans.predict(features_test)

#separate time steps by label
dates_by_label_test = {i: sorted(features_test.loc[features_test.label==i].index) for i in range(nclusters)}

#separate dataset by labels
dss_by_label_test = {i: test.sel({'time': dates_by_label_test[i]}) for i in range(nclusters)}

#export test matched dss by label
test_resulting_dss = {i: fuser.export_matching_ds(dss_by_label_test[i], params=params_by_label[i]) for i in range(nclusters)}

#ensure no duplicates and set them to be merged
test_land_dss = []
for label in range(nclusters):
    fused_ds = test_resulting_dss[label]
    land_ds = fused_ds.drop_duplicates('time')
    test_land_dss.append(land_ds)

#merge them
test_merged = xr.merge(test_land_dss)

#bias evaluation
no_match_bias = metrics.calc_rel_bias(test_merged.drop_vars('imerg_v7_matched'), char_pcp='rain')
matched_bias = metrics.calc_rel_bias(test_merged.drop_vars('imerg_v7'), char_pcp='rain')

print('\nfor test dataset')
print(f'no matching:\t{no_match_bias}\nmatching:\t{matched_bias}')
# Out:
# /home/admingosset/WORK/code/PACHA/pacha/merging/quantile_matching.py:55: OptimizeWarning: Covariance of the parameters could not be estimated
#   popt, pcov = curve_fit(fit_func, x, y, maxfev=100000)
# /home/admingosset/WORK/code/PACHA/pacha/merging/quantile_matching.py:55: OptimizeWarning: Covariance of the parameters could not be estimated
#   popt, pcov = curve_fit(fit_func, x, y, maxfev=100000)
# /home/admingosset/WORK/code/PACHA/pacha/merging/quantile_matching.py:55: OptimizeWarning: Covariance of the parameters could not be estimated
#   popt, pcov = curve_fit(fit_func, x, y, maxfev=100000)
# /home/admingosset/WORK/code/PACHA/pacha/merging/quantile_matching.py:55: OptimizeWarning: Covariance of the parameters could not be estimated
#   popt, pcov = curve_fit(fit_func, x, y, maxfev=100000)
# /home/admingosset/WORK/code/PACHA/pacha/merging/quantile_matching.py:55: OptimizeWarning: Covariance of the parameters could not be estimated
#   popt, pcov = curve_fit(fit_func, x, y, maxfev=100000)
# /home/admingosset/WORK/code/PACHA/pacha/merging/quantile_matching.py:55: OptimizeWarning: Covariance of the parameters could not be estimated
#   popt, pcov = curve_fit(fit_func, x, y, maxfev=100000)
# /home/admingosset/WORK/code/PACHA/pacha/merging/quantile_matching.py:55: OptimizeWarning: Covariance of the parameters could not be estimated
#   popt, pcov = curve_fit(fit_func, x, y, maxfev=100000)
# /home/admingosset/WORK/code/PACHA/pacha/merging/quantile_matching.py:55: OptimizeWarning: Covariance of the parameters could not be estimated
#   popt, pcov = curve_fit(fit_func, x, y, maxfev=100000)
# for train dataset
# no matching:	{'relative_bias': np.float64(-0.1272)}
# matching:	{'relative_bias': np.float64(0.0101)}
#
# for test dataset
# no matching:	{'relative_bias': np.float64(-0.1352)}
# matching:	{'relative_bias': np.float64(0.0084)}

# %%
### test applying wlsewhere

#ime_cropped_df = futils.get_df_dates_filepaths('/media/rzambranap/MG_exfat/data/processed_data/guyane/imerg_late_cropped/', date_char_st=19, date_char_nd=29, date_format='%Y_%m_%d')
ime_cropped_df = futils.get_df_dates_filepaths('/media/admingosset/T7Shield/data/data_pc_linux/raw_data/IMERG_Late_v07/downloads/')

ime_cropped_df = ime_cropped_df.sort_index()

# %%
from pacha.utils import instruments as iutils

satv7 = iutils.SPP('imerg_v7', 'imerg_late_v07')
v7_path = '/media/admingosset/T7Shield/data/data_pc_linux/raw_data/IMERG_Late_v07/downloads/'

# %%
satv7.build_catalog(2, v7_path)

# %%
path_to_file = '/media/admingosset/MG_exfat/data/processed_data/guyane/imerg_late_cropped/imerg_late_cropped_2019_01_01_V000.nc'
ds_sample = xr.open_dataset(path_to_file)

# %%
bbox = gutils.get_bbox_from_xarray(ds_sample)

# %%
from pacha.data_sources import satellite_loaders as sload

i = 0
# get single dates from ime_cropped_df
single_dates = sorted(list(set([i.date() for i in ime_cropped_df.index.tolist()])))
for day in single_dates:
    print(day)
    ime_ds = sload.load_v7_by_date(satv7, str(day), field='precipitation')
    ime_ds = gutils.get_data_in_bbox(ime_ds.to_dataset(), bbox)
    
    ime_subdivided = subdivide_dataset(ime_ds, 2)
    # correct each subdivision
    subds_corrected = []
    for subdivision in ime_subdivided:
        # features
        feats_df = calculate_features_for_clustering(subdivision)['precipitation']
        feats_df = feats_df.fillna(20)
        #add labels
        nclusters = kmeans.n_clusters
        feats_df.loc[:, 'label'] = kmeans.predict(feats_df)
        #separate time steps by label
        dates_by_label = {i: sorted(feats_df.loc[feats_df.label==i].index) for i in range(nclusters)}
        
        #separate dataset by labels
        dss_by_label = {i: subdivision.sel({'time': dates_by_label[i]}) for i in range(nclusters)}
        for key in dss_by_label.keys():
            dss_by_label[key] = dss_by_label[key].where(dss_by_label[key].precipitation > 0)
        #export train matched dss by label
        subds_resulting_dss = {i: fuser.apply_params(dss_by_label[i], params_by_label[i]) for i in range(nclusters)}
        #ensure no duplicates and set them to be merged
        subds_land_dss = []
        for label in range(nclusters):
            fused_ds = subds_resulting_dss[label]
            land_ds = fused_ds.drop_duplicates('time')
            subds_land_dss.append(land_ds)
        
        #merge them
        subds_merged = xr.merge(subds_land_dss)
        subds_corrected.append(subds_merged)
    merged_subds = xr.merge(subds_corrected)
    merged_subds = merged_subds.fillna(0)
    fname = f"imerg_latev7_fused_{dt.strftime(day, format='%Y_%m_%d')}_V005.nc"
    fpath = f'/media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/{fname}'
    merged_subds.to_netcdf(fpath)
    print(f'saved to {fpath}')
# Out:
# 2015-01-01
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_01_01_V005.nc
# 2015-01-02
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_01_02_V005.nc
# 2015-01-03
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_01_03_V005.nc
# 2015-01-04
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_01_04_V005.nc
# 2015-01-05
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_01_05_V005.nc
# 2015-01-06
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_01_06_V005.nc
# 2015-01-07
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_01_07_V005.nc
# 2015-01-08
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_01_08_V005.nc
# 2015-01-09
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_01_09_V005.nc
# 2015-01-10
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_01_10_V005.nc
# 2015-01-11
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_01_11_V005.nc
# 2015-01-12
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_01_12_V005.nc
# 2015-01-13
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_01_13_V005.nc
# 2015-01-14
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_01_14_V005.nc
# 2015-01-15
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_01_15_V005.nc
# 2015-01-16
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_01_16_V005.nc
# 2015-01-17
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_01_17_V005.nc
# 2015-01-18
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_01_18_V005.nc
# 2015-01-19
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_01_19_V005.nc
# 2015-01-20
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_01_20_V005.nc
# 2015-01-21
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_01_21_V005.nc
# 2015-01-22
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_01_22_V005.nc
# 2015-01-23
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_01_23_V005.nc
# 2015-01-24
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_01_24_V005.nc
# 2015-01-25
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_01_25_V005.nc
# 2015-01-26
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_01_26_V005.nc
# 2015-01-27
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_01_27_V005.nc
# 2015-01-28
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_01_28_V005.nc
# 2015-01-29
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_01_29_V005.nc
# 2015-01-30
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_01_30_V005.nc
# 2015-01-31
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_01_31_V005.nc
# 2015-02-01
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_02_01_V005.nc
# 2015-02-02
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_02_02_V005.nc
# 2015-02-03
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_02_03_V005.nc
# 2015-02-04
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_02_04_V005.nc
# 2015-02-05
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_02_05_V005.nc
# 2015-02-06
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_02_06_V005.nc
# 2015-02-07
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_02_07_V005.nc
# 2015-02-08
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_02_08_V005.nc
# 2015-02-09
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_02_09_V005.nc
# 2015-02-10
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_02_10_V005.nc
# 2015-02-11
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_02_11_V005.nc
# 2015-02-12
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_02_12_V005.nc
# 2015-02-13
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_02_13_V005.nc
# 2015-02-14
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_02_14_V005.nc
# 2015-02-15
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_02_15_V005.nc
# 2015-02-16
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_02_16_V005.nc
# 2015-02-17
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_02_17_V005.nc
# 2015-02-18
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_02_18_V005.nc
# 2015-02-19
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_02_19_V005.nc
# 2015-02-20
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_02_20_V005.nc
# 2015-02-21
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_02_21_V005.nc
# 2015-02-22
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_02_22_V005.nc
# 2015-02-23
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_02_23_V005.nc
# 2015-02-24
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_02_24_V005.nc
# 2015-02-25
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_02_25_V005.nc
# 2015-02-26
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_02_26_V005.nc
# 2015-02-27
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_02_27_V005.nc
# 2015-02-28
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_02_28_V005.nc
# 2015-03-01
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_03_01_V005.nc
# 2015-03-02
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_03_02_V005.nc
# 2015-03-03
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_03_03_V005.nc
# 2015-03-04
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_03_04_V005.nc
# 2015-03-05
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_03_05_V005.nc
# 2015-03-06
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_03_06_V005.nc
# 2015-03-07
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_03_07_V005.nc
# 2015-03-08
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_03_08_V005.nc
# 2015-03-09
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_03_09_V005.nc
# 2015-03-10
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_03_10_V005.nc
# 2015-03-11
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_03_11_V005.nc
# 2015-03-12
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_03_12_V005.nc
# 2015-03-13
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_03_13_V005.nc
# 2015-03-14
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_03_14_V005.nc
# 2015-03-15
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_03_15_V005.nc
# 2015-03-16
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_03_16_V005.nc
# 2015-03-17
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_03_17_V005.nc
# 2015-03-18
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_03_18_V005.nc
# 2015-03-19
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_03_19_V005.nc
# 2015-03-20
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_03_20_V005.nc
# 2015-03-21
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_03_21_V005.nc
# 2015-03-22
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_03_22_V005.nc
# 2015-03-23
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_03_23_V005.nc
# 2015-03-24
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_03_24_V005.nc
# 2015-03-25
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_03_25_V005.nc
# 2015-03-26
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_03_26_V005.nc
# 2015-03-27
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_03_27_V005.nc
# 2015-03-28
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_03_28_V005.nc
# 2015-03-29
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_03_29_V005.nc
# 2015-03-30
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_03_30_V005.nc
# 2015-03-31
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_03_31_V005.nc
# 2015-04-01
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_04_01_V005.nc
# 2015-04-02
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_04_02_V005.nc
# 2015-04-03
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_04_03_V005.nc
# 2015-04-04
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_04_04_V005.nc
# 2015-04-05
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_04_05_V005.nc
# 2015-04-06
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_04_06_V005.nc
# 2015-04-07
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_04_07_V005.nc
# 2015-04-08
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_04_08_V005.nc
# 2015-04-09
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_04_09_V005.nc
# 2015-04-10
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_04_10_V005.nc
# 2015-04-11
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_04_11_V005.nc
# 2015-04-12
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_04_12_V005.nc
# 2015-04-13
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_04_13_V005.nc
# 2015-04-14
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_04_14_V005.nc
# 2015-04-15
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_04_15_V005.nc
# 2015-04-16
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_04_16_V005.nc
# 2015-04-17
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_04_17_V005.nc
# 2015-04-18
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_04_18_V005.nc
# 2015-04-19
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_04_19_V005.nc
# 2015-04-20
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_04_20_V005.nc
# 2015-04-21
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_04_21_V005.nc
# 2015-04-22
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_04_22_V005.nc
# 2015-04-23
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_04_23_V005.nc
# 2015-04-24
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_04_24_V005.nc
# 2015-04-25
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_04_25_V005.nc
# 2015-04-26
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_04_26_V005.nc
# 2015-04-27
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_04_27_V005.nc
# 2015-04-28
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_04_28_V005.nc
# 2015-04-29
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_04_29_V005.nc
# 2015-04-30
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_04_30_V005.nc
# 2015-05-01
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_05_01_V005.nc
# 2015-05-02
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_05_02_V005.nc
# 2015-05-03
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_05_03_V005.nc
# 2015-05-04
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_05_04_V005.nc
# 2015-05-05
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_05_05_V005.nc
# 2015-05-06
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_05_06_V005.nc
# 2015-05-07
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_05_07_V005.nc
# 2015-05-08
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_05_08_V005.nc
# 2015-05-09
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_05_09_V005.nc
# 2015-05-10
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_05_10_V005.nc
# 2015-05-11
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_05_11_V005.nc
# 2015-05-12
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_05_12_V005.nc
# 2015-05-13
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_05_13_V005.nc
# 2015-05-14
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_05_14_V005.nc
# 2015-05-15
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_05_15_V005.nc
# 2015-05-16
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_05_16_V005.nc
# 2015-05-17
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_05_17_V005.nc
# 2015-05-18
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_05_18_V005.nc
# 2015-05-19
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_05_19_V005.nc
# 2015-05-20
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_05_20_V005.nc
# 2015-05-21
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_05_21_V005.nc
# 2015-05-22
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_05_22_V005.nc
# 2015-05-23
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_05_23_V005.nc
# 2015-05-24
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_05_24_V005.nc
# 2015-05-25
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_05_25_V005.nc
# 2015-05-26
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_05_26_V005.nc
# 2015-05-27
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_05_27_V005.nc
# 2015-05-28
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_05_28_V005.nc
# 2015-05-29
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_05_29_V005.nc
# 2015-05-30
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_05_30_V005.nc
# 2015-05-31
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_05_31_V005.nc
# 2015-06-01
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_06_01_V005.nc
# 2015-06-02
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_06_02_V005.nc
# 2015-06-03
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_06_03_V005.nc
# 2015-06-04
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_06_04_V005.nc
# 2015-06-05
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_06_05_V005.nc
# 2015-06-06
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_06_06_V005.nc
# 2015-06-07
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_06_07_V005.nc
# 2015-06-08
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_06_08_V005.nc
# 2015-06-09
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_06_09_V005.nc
# 2015-06-10
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_06_10_V005.nc
# 2015-06-11
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_06_11_V005.nc
# 2015-06-12
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_06_12_V005.nc
# 2015-06-13
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_06_13_V005.nc
# 2015-06-14
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_06_14_V005.nc
# 2015-06-15
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_06_15_V005.nc
# 2015-06-16
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_06_16_V005.nc
# 2015-06-17
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_06_17_V005.nc
# 2015-06-18
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_06_18_V005.nc
# 2015-06-19
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_06_19_V005.nc
# 2015-06-20
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_06_20_V005.nc
# 2015-06-21
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_06_21_V005.nc
# 2015-06-22
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_06_22_V005.nc
# 2015-06-23
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_06_23_V005.nc
# 2015-06-24
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_06_24_V005.nc
# 2015-06-25
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_06_25_V005.nc
# 2015-06-26
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_06_26_V005.nc
# 2015-06-27
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_06_27_V005.nc
# 2015-06-28
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_06_28_V005.nc
# 2015-06-29
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_06_29_V005.nc
# 2015-06-30
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_06_30_V005.nc
# 2015-07-01
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_07_01_V005.nc
# 2015-07-02
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_07_02_V005.nc
# 2015-07-03
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_07_03_V005.nc
# 2015-07-04
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_07_04_V005.nc
# 2015-07-05
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_07_05_V005.nc
# 2015-07-06
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_07_06_V005.nc
# 2015-07-07
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_07_07_V005.nc
# 2015-07-08
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_07_08_V005.nc
# 2015-07-09
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_07_09_V005.nc
# 2015-07-10
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_07_10_V005.nc
# 2015-07-11
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_07_11_V005.nc
# 2015-07-12
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_07_12_V005.nc
# 2015-07-13
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_07_13_V005.nc
# 2015-07-14
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_07_14_V005.nc
# 2015-07-15
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_07_15_V005.nc
# 2015-07-16
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_07_16_V005.nc
# 2015-07-17
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_07_17_V005.nc
# 2015-07-18
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_07_18_V005.nc
# 2015-07-19
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_07_19_V005.nc
# 2015-07-20
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_07_20_V005.nc
# 2015-07-21
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_07_21_V005.nc
# 2015-07-22
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_07_22_V005.nc
# 2015-07-23
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_07_23_V005.nc
# 2015-07-24
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_07_24_V005.nc
# 2015-07-25
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_07_25_V005.nc
# 2015-07-26
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_07_26_V005.nc
# 2015-07-27
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_07_27_V005.nc
# 2015-07-28
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_07_28_V005.nc
# 2015-07-29
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_07_29_V005.nc
# 2015-07-30
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_07_30_V005.nc
# 2015-07-31
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_07_31_V005.nc
# 2015-08-01
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_08_01_V005.nc
# 2015-08-02
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_08_02_V005.nc
# 2015-08-03
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_08_03_V005.nc
# 2015-08-04
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_08_04_V005.nc
# 2015-08-05
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_08_05_V005.nc
# 2015-08-06
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_08_06_V005.nc
# 2015-08-07
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_08_07_V005.nc
# 2015-08-08
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_08_08_V005.nc
# 2015-08-09
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_08_09_V005.nc
# 2015-08-10
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_08_10_V005.nc
# 2015-08-11
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_08_11_V005.nc
# 2015-08-12
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_08_12_V005.nc
# 2015-08-13
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_08_13_V005.nc
# 2015-08-14
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_08_14_V005.nc
# 2015-08-15
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_08_15_V005.nc
# 2015-08-16
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_08_16_V005.nc
# 2015-08-17
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_08_17_V005.nc
# 2015-08-18
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_08_18_V005.nc
# 2015-08-19
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_08_19_V005.nc
# 2015-08-20
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_08_20_V005.nc
# 2015-08-21
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_08_21_V005.nc
# 2015-08-22
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_08_22_V005.nc
# 2015-08-23
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_08_23_V005.nc
# 2015-08-24
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_08_24_V005.nc
# 2015-08-25
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_08_25_V005.nc
# 2015-08-26
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_08_26_V005.nc
# 2015-08-27
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_08_27_V005.nc
# 2015-08-28
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_08_28_V005.nc
# 2015-08-29
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_08_29_V005.nc
# 2015-08-30
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_08_30_V005.nc
# 2015-08-31
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_08_31_V005.nc
# 2015-09-01
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_09_01_V005.nc
# 2015-09-02
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_09_02_V005.nc
# 2015-09-03
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_09_03_V005.nc
# 2015-09-04
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_09_04_V005.nc
# 2015-09-05
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_09_05_V005.nc
# 2015-09-06
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_09_06_V005.nc
# 2015-09-07
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_09_07_V005.nc
# 2015-09-08
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_09_08_V005.nc
# 2015-09-09
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_09_09_V005.nc
# 2015-09-10
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_09_10_V005.nc
# 2015-09-11
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_09_11_V005.nc
# 2015-09-12
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_09_12_V005.nc
# 2015-09-13
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_09_13_V005.nc
# 2015-09-14
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_09_14_V005.nc
# 2015-09-15
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_09_15_V005.nc
# 2015-09-16
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_09_16_V005.nc
# 2015-09-17
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_09_17_V005.nc
# 2015-09-18
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_09_18_V005.nc
# 2015-09-19
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_09_19_V005.nc
# 2015-09-20
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_09_20_V005.nc
# 2015-09-21
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_09_21_V005.nc
# 2015-09-22
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_09_22_V005.nc
# 2015-09-23
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_09_23_V005.nc
# 2015-09-24
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_09_24_V005.nc
# 2015-09-25
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_09_25_V005.nc
# 2015-09-26
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_09_26_V005.nc
# 2015-09-27
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_09_27_V005.nc
# 2015-09-28
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_09_28_V005.nc
# 2015-09-29
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_09_29_V005.nc
# 2015-09-30
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_09_30_V005.nc
# 2015-10-01
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_10_01_V005.nc
# 2015-10-02
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_10_02_V005.nc
# 2015-10-03
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_10_03_V005.nc
# 2015-10-04
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_10_04_V005.nc
# 2015-10-05
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_10_05_V005.nc
# 2015-10-06
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_10_06_V005.nc
# 2015-10-07
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_10_07_V005.nc
# 2015-10-08
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_10_08_V005.nc
# 2015-10-09
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_10_09_V005.nc
# 2015-10-10
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_10_10_V005.nc
# 2015-10-11
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_10_11_V005.nc
# 2015-10-12
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_10_12_V005.nc
# 2015-10-13
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_10_13_V005.nc
# 2015-10-14
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_10_14_V005.nc
# 2015-10-15
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_10_15_V005.nc
# 2015-10-16
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_10_16_V005.nc
# 2015-10-17
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_10_17_V005.nc
# 2015-10-18
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_10_18_V005.nc
# 2015-10-19
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_10_19_V005.nc
# 2015-10-20
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_10_20_V005.nc
# 2015-10-21
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_10_21_V005.nc
# 2015-10-22
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_10_22_V005.nc
# 2015-10-23
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_10_23_V005.nc
# 2015-10-24
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_10_24_V005.nc
# 2015-10-25
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_10_25_V005.nc
# 2015-10-26
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_10_26_V005.nc
# 2015-10-27
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_10_27_V005.nc
# 2015-10-28
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_10_28_V005.nc
# 2015-10-29
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_10_29_V005.nc
# 2015-10-30
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_10_30_V005.nc
# 2015-10-31
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_10_31_V005.nc
# 2015-11-01
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_11_01_V005.nc
# 2015-11-02
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_11_02_V005.nc
# 2015-11-03
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_11_03_V005.nc
# 2015-11-04
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_11_04_V005.nc
# 2015-11-05
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_11_05_V005.nc
# 2015-11-06
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_11_06_V005.nc
# 2015-11-07
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_11_07_V005.nc
# 2015-11-08
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_11_08_V005.nc
# 2015-11-09
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_11_09_V005.nc
# 2015-11-10
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_11_10_V005.nc
# 2015-11-11
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_11_11_V005.nc
# 2015-11-12
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_11_12_V005.nc
# 2015-11-13
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_11_13_V005.nc
# 2015-11-14
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_11_14_V005.nc
# 2015-11-15
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_11_15_V005.nc
# 2015-11-16
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_11_16_V005.nc
# 2015-11-17
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_11_17_V005.nc
# 2015-11-18
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_11_18_V005.nc
# 2015-11-19
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_11_19_V005.nc
# 2015-11-20
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_11_20_V005.nc
# 2015-11-21
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_11_21_V005.nc
# 2015-11-22
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_11_22_V005.nc
# 2015-11-23
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_11_23_V005.nc
# 2015-11-24
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_11_24_V005.nc
# 2015-11-25
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_11_25_V005.nc
# 2015-11-26
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_11_26_V005.nc
# 2015-11-27
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_11_27_V005.nc
# 2015-11-28
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_11_28_V005.nc
# 2015-11-29
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_11_29_V005.nc
# 2015-11-30
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_11_30_V005.nc
# 2015-12-01
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_12_01_V005.nc
# 2015-12-02
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_12_02_V005.nc
# 2015-12-03
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_12_03_V005.nc
# 2015-12-04
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_12_04_V005.nc
# 2015-12-05
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_12_05_V005.nc
# 2015-12-06
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_12_06_V005.nc
# 2015-12-07
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_12_07_V005.nc
# 2015-12-08
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_12_08_V005.nc
# 2015-12-09
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_12_09_V005.nc
# 2015-12-10
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_12_10_V005.nc
# 2015-12-11
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_12_11_V005.nc
# 2015-12-12
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_12_12_V005.nc
# 2015-12-13
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_12_13_V005.nc
# 2015-12-14
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_12_14_V005.nc
# 2015-12-15
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_12_15_V005.nc
# 2015-12-16
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_12_16_V005.nc
# 2015-12-17
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_12_17_V005.nc
# 2015-12-18
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_12_18_V005.nc
# 2015-12-19
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_12_19_V005.nc
# 2015-12-20
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_12_20_V005.nc
# 2015-12-21
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_12_21_V005.nc
# 2015-12-22
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_12_22_V005.nc
# 2015-12-23
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_12_23_V005.nc
# 2015-12-24
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_12_24_V005.nc
# 2015-12-25
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_12_25_V005.nc
# 2015-12-26
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_12_26_V005.nc
# 2015-12-27
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_12_27_V005.nc
# 2015-12-28
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_12_28_V005.nc
# 2015-12-29
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_12_29_V005.nc
# 2015-12-30
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_12_30_V005.nc
# 2015-12-31
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2015_12_31_V005.nc
# 2016-01-01
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2016_01_01_V005.nc
# 2016-01-02
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2016_01_02_V005.nc
# 2016-01-03
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2016_01_03_V005.nc
# 2016-01-04
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2016_01_04_V005.nc
# 2016-01-05
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2016_01_05_V005.nc
# 2016-01-06
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2016_01_06_V005.nc
# 2016-01-07
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2016_01_07_V005.nc
# 2016-01-08
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2016_01_08_V005.nc
# 2016-01-09
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2016_01_09_V005.nc
# 2016-01-10
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2016_01_10_V005.nc
# 2016-01-11
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2016_01_11_V005.nc
# 2016-01-12
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2016_01_12_V005.nc
# 2016-01-13
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2016_01_13_V005.nc
# 2016-01-14
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2016_01_14_V005.nc
# 2016-01-15
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2016_01_15_V005.nc
# 2016-01-16
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2016_01_16_V005.nc
# 2016-01-17
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2016_01_17_V005.nc
# 2016-01-18
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2016_01_18_V005.nc
# 2016-01-19
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2016_01_19_V005.nc
# 2016-01-20
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2016_01_20_V005.nc
# 2016-01-21
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2016_01_21_V005.nc
# 2016-01-22
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2016_01_22_V005.nc
# 2016-01-23
# ...
# 2025-01-24
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_01_24_V005.nc
# 2025-01-25
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_01_25_V005.nc
# 2025-01-26
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_01_26_V005.nc
# 2025-01-27
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_01_27_V005.nc
# 2025-01-28
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_01_28_V005.nc
# 2025-01-29
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_01_29_V005.nc
# 2025-01-30
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_01_30_V005.nc
# 2025-01-31
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_01_31_V005.nc
# 2025-02-01
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_02_01_V005.nc
# 2025-02-02
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_02_02_V005.nc
# 2025-02-03
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_02_03_V005.nc
# 2025-02-04
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_02_04_V005.nc
# 2025-02-05
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_02_05_V005.nc
# 2025-02-06
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_02_06_V005.nc
# 2025-02-07
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_02_07_V005.nc
# 2025-02-08
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_02_08_V005.nc
# 2025-02-09
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_02_09_V005.nc
# 2025-02-10
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_02_10_V005.nc
# 2025-02-11
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_02_11_V005.nc
# 2025-02-12
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_02_12_V005.nc
# 2025-02-13
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_02_13_V005.nc
# 2025-02-14
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_02_14_V005.nc
# 2025-02-15
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_02_15_V005.nc
# 2025-02-16
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_02_16_V005.nc
# 2025-02-17
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_02_17_V005.nc
# 2025-02-18
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_02_18_V005.nc
# 2025-02-19
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_02_19_V005.nc
# 2025-02-20
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_02_20_V005.nc
# 2025-02-21
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_02_21_V005.nc
# 2025-02-22
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_02_22_V005.nc
# 2025-02-23
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_02_23_V005.nc
# 2025-02-24
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_02_24_V005.nc
# 2025-02-25
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_02_25_V005.nc
# 2025-02-26
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_02_26_V005.nc
# 2025-02-27
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_02_27_V005.nc
# 2025-02-28
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_02_28_V005.nc
# 2025-03-01
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_03_01_V005.nc
# 2025-03-02
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_03_02_V005.nc
# 2025-03-03
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_03_03_V005.nc
# 2025-03-04
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_03_04_V005.nc
# 2025-03-05
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_03_05_V005.nc
# 2025-03-06
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_03_06_V005.nc
# 2025-03-07
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_03_07_V005.nc
# 2025-03-08
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_03_08_V005.nc
# 2025-03-09
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_03_09_V005.nc
# 2025-03-10
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_03_10_V005.nc
# 2025-03-11
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_03_11_V005.nc
# 2025-03-12
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_03_12_V005.nc
# 2025-03-13
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_03_13_V005.nc
# 2025-03-14
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_03_14_V005.nc
# 2025-03-15
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_03_15_V005.nc
# 2025-03-16
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_03_16_V005.nc
# 2025-03-17
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_03_17_V005.nc
# 2025-03-18
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_03_18_V005.nc
# 2025-03-19
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_03_19_V005.nc
# 2025-03-20
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_03_20_V005.nc
# 2025-03-21
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_03_21_V005.nc
# 2025-03-22
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_03_22_V005.nc
# 2025-03-23
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_03_23_V005.nc
# 2025-03-24
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_03_24_V005.nc
# 2025-03-25
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_03_25_V005.nc
# 2025-03-26
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_03_26_V005.nc
# 2025-03-27
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_03_27_V005.nc
# 2025-03-28
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_03_28_V005.nc
# 2025-03-29
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_03_29_V005.nc
# 2025-03-30
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_03_30_V005.nc
# 2025-03-31
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_03_31_V005.nc
# 2025-04-01
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_04_01_V005.nc
# 2025-04-02
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_04_02_V005.nc
# 2025-04-03
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_04_03_V005.nc
# 2025-04-04
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_04_04_V005.nc
# 2025-04-05
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_04_05_V005.nc
# 2025-04-06
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_04_06_V005.nc
# 2025-04-07
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_04_07_V005.nc
# 2025-04-08
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_04_08_V005.nc
# 2025-04-09
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_04_09_V005.nc
# 2025-04-10
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_04_10_V005.nc
# 2025-04-11
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_04_11_V005.nc
# 2025-04-12
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_04_12_V005.nc
# 2025-04-13
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_04_13_V005.nc
# 2025-04-14
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_04_14_V005.nc
# 2025-04-15
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_04_15_V005.nc
# 2025-04-16
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_04_16_V005.nc
# 2025-04-17
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_04_17_V005.nc
# 2025-04-18
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_04_18_V005.nc
# 2025-04-19
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_04_19_V005.nc
# 2025-04-20
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_04_20_V005.nc
# 2025-04-21
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_04_21_V005.nc
# 2025-04-22
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_04_22_V005.nc
# 2025-04-23
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_04_23_V005.nc
# 2025-04-24
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_04_24_V005.nc
# 2025-04-25
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_04_25_V005.nc
# 2025-04-26
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_04_26_V005.nc
# 2025-04-27
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_04_27_V005.nc
# 2025-04-28
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_04_28_V005.nc
# 2025-04-29
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_04_29_V005.nc
# 2025-04-30
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_04_30_V005.nc
# 2025-05-01
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_05_01_V005.nc
# 2025-05-02
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_05_02_V005.nc
# 2025-05-03
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_05_03_V005.nc
# 2025-05-04
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_05_04_V005.nc
# 2025-05-05
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_05_05_V005.nc
# 2025-05-06
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_05_06_V005.nc
# 2025-05-07
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_05_07_V005.nc
# 2025-05-08
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_05_08_V005.nc
# 2025-05-09
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_05_09_V005.nc
# 2025-05-10
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_05_10_V005.nc
# 2025-05-11
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_05_11_V005.nc
# 2025-05-12
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_05_12_V005.nc
# 2025-05-13
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_05_13_V005.nc
# 2025-05-14
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_05_14_V005.nc
# 2025-05-15
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_05_15_V005.nc
# 2025-05-16
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_05_16_V005.nc
# 2025-05-17
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_05_17_V005.nc
# 2025-05-18
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_05_18_V005.nc
# 2025-05-19
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_05_19_V005.nc
# 2025-05-20
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_05_20_V005.nc
# 2025-05-21
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_05_21_V005.nc
# 2025-05-22
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_05_22_V005.nc
# 2025-05-23
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_05_23_V005.nc
# 2025-05-24
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_05_24_V005.nc
# 2025-05-25
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_05_25_V005.nc
# 2025-05-26
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_05_26_V005.nc
# 2025-05-27
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_05_27_V005.nc
# 2025-05-28
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_05_28_V005.nc
# 2025-05-29
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_05_29_V005.nc
# 2025-05-30
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_05_30_V005.nc
# 2025-05-31
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_05_31_V005.nc
# 2025-06-01
# saved to /media/admingosset/T7Shield/data/processed_data/guyane/sat_v7_qmp/imerg_latev7_fused_2025_06_01_V005.nc

# %%
params_by_label
# Out:
# {0: {'land_params': {'method': 'qmatch_by_parts',
#    'offset': array(0.28),
#    'p1_popt': array([-7.8845103 ,  3.09545874,  0.05430687]),
#    'p2_popt': array([ 0.05024228,  1.41306928, -0.56409719]),
#    'func': <function __main__.test_func(x, a, b, c)>},
#   'sea_params': {'method': 'qmatch_by_parts',
#    'offset': array(0.29999998),
#    'p1_popt': array([-3.59585767,  1.94837784,  0.01594867]),
#    'p2_popt': array([-0.01049602,  2.27748851, -0.65378323]),
#    'func': <function __main__.test_func(x, a, b, c)>}},
#  1: {'land_params': {'method': 'qmatch_by_parts',
#    'offset': array(3.03999996),
#    'p1_popt': array([0.09188441, 0.27139429, 0.05109435]),
#    'p2_popt': array([-0.00786147,  1.4993736 , -3.12235754]),
#    'func': <function __main__.test_func(x, a, b, c)>},
#   'sea_params': {'method': 'qmatch_by_parts',
#    'offset': array(1.93999994),
#    'p1_popt': array([0.10051799, 0.65608267, 0.01131544]),
#    'p2_popt': array([-0.00155365,  1.20231203, -0.59351105]),
#    'func': <function __main__.test_func(x, a, b, c)>}},
#  2: {'land_params': {'method': 'qmatch_by_parts',
#    'offset': array(0.),
#    'p1_popt': array([1.0000000e+00, 1.0000000e+00, 1.9311315e-26]),
#    'p2_popt': array([-0.30477232,  4.48554727,  0.16862981]),
#    'func': <function __main__.test_func(x, a, b, c)>},
#   'sea_params': {'method': 'qmatch_by_parts',
#    'offset': array(0.),
#    'p1_popt': array([1.0000000e+00, 1.0000000e+00, 1.9311315e-26]),
#    'p2_popt': array([-0.4692104 ,  4.76597812,  0.10280709]),
#    'func': <function __main__.test_func(x, a, b, c)>}},
#  3: {'land_params': {'method': 'qmatch_by_parts',
#    'offset': array(0.),
#    'p1_popt': array([1.        , 1.        , 0.00223244]),
#    'p2_popt': array([-0.00445172,  2.2822975 ,  0.27504163]),
#    'func': <function __main__.test_func(x, a, b, c)>},
#   'sea_params': {'method': 'qmatch_by_parts',
#    'offset': array(0.),
#    'p1_popt': array([1.       , 1.       , 0.0055427]),
#    'p2_popt': array([-0.0740338 ,  3.69330281,  0.17988313]),
#    'func': <function __main__.test_func(x, a, b, c)>}}}

# %%
nclusters
# Out:
# 4

# %%
gvis.plot_simple_map()
ime_ds.isel({'time':0}).plot(x='lon', y='lat')

plt.show()

gvis.plot_simple_map()
ime_subdivided[2].isel({'time':0}).plot(x='lon', y='lat')

# %%
ime_ds
# Out:
# <xarray.Dataset> Size: 23MB
# Dimensions:                         (time: 48, lon: 106, lat: 103, latv: 2,
#                                      nv: 2, lonv: 2)
# Coordinates:
#   * lat                             (lat) float32 412B -1.75 -1.65 ... 8.35 8.45
#   * latv                            (latv) int32 8B 0 1
#   * lon                             (lon) float32 424B -58.55 -58.45 ... -48.05
#   * lonv                            (lonv) int32 8B 0 1
#   * nv                              (nv) int32 8B 0 1
#   * time                            (time) object 384B 2015-01-01 00:00:00 .....
# Data variables: (12/13)
#     MWprecipitation                 (time, lon, lat) float32 2MB dask.array<chunksize=(1, 106, 103), meta=np.ndarray>
#     MWobservationTime               (time, lon, lat) timedelta64[ns] 4MB dask.array<chunksize=(1, 106, 103), meta=np.ndarray>
#     IRprecipitation                 (time, lon, lat) float32 2MB dask.array<chunksize=(1, 106, 103), meta=np.ndarray>
#     MWprecipSource                  (time, lon, lat) float32 2MB dask.array<chunksize=(1, 106, 103), meta=np.ndarray>
#     IRinfluence                     (time, lon, lat) float32 2MB dask.array<chunksize=(1, 106, 103), meta=np.ndarray>
#     precipitationUncal              (time, lon, lat) float32 2MB dask.array<chunksize=(1, 106, 103), meta=np.ndarray>
#     ...                              ...
#     lat_bnds                        (time, lat, latv) float32 40kB dask.array<chunksize=(1, 103, 2), meta=np.ndarray>
#     precipitation                   (time, lon, lat) float32 2MB dask.array<chunksize=(1, 106, 103), meta=np.ndarray>
#     probabilityLiquidPrecipitation  (time, lon, lat) float32 2MB dask.array<chunksize=(1, 106, 103), meta=np.ndarray>
#     randomError                     (time, lon, lat) float32 2MB dask.array<chunksize=(1, 106, 103), meta=np.ndarray>
#     time_bnds                       (time, nv) object 768B dask.array<chunksize=(1, 2), meta=np.ndarray>
#     lon_bnds                        (time, lon, lonv) float32 41kB dask.array<chunksize=(1, 106, 2), meta=np.ndarray>
# Attributes:
#     FileHeader:                      DOI=10.5067/GPM/IMERG/3B-HH-L/07;\nDOIau...
#     FileInfo:                        DataFormatVersion=7e;\nTKCodeBuildVersio...
#     history:                         2025-06-02 22:45:01 GMT hyrax-1.17.1 htt...
#     history_json:                    [{"$schema":"https:\/\/harmony.earthdata...
#     Grid.GridHeader:                 BinMethod=ARITHMETIC_MEAN;\nRegistration...
#     Grid.fullnamepath:               /Grid
#     DODS_EXTRA.Unlimited_Dimension:  time

# %%
help(sload.load_v7_by_date)
# Out:
# Help on function load_v7_by_date in module pacha.data_sources.satellite_loaders:
#
# load_v7_by_date(sat_v7, date, field=None)
